# %% [markdown]
# <a href="https://colab.research.google.com/github/5ilvi4/test-epcath/blob/master/EP_CATH_Python_Code_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### EP_CATH Python Code
# adapted from @nicseo 11/20/14. Last updated @cindiewu 07/14/20.
# ##### To start a new simulation, go to the menu Runtime --> 'Restart and Run All'

# %%
# !git clone https://github.com/empracine/test-epcath.git
# Out:
# fatal: destination path 'test-epcath' already exists and is not an empty directory.

# %%
#Click this kernel to when starting the simulation (and/or run another scenario)
import os
os.chdir("/content/test-epcath/")

import Simulation
Simulation.Start()
# Out:
# Starting...
# VBox(children=(Label(value='SET THE FOLLOWING PARAMETERS, THEN CLICK GO!', layout=Layout(height='80%', width='…
# Button(description='Go!', style=ButtonStyle())
# Output()

# %%
# %cd /content
# !rm -rf /content/test-epcath
# !git clone https://github.com/5ilvi4/test-epcath.git
# Out:
# /content
# Cloning into 'test-epcath'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 200 (delta 57), reused 0 (delta 0), pack-reused 95 (from 1)
# Receiving objects: 100% (200/200), 1.14 MiB | 4.40 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
import os, sys, importlib
os.chdir("/content/test-epcath")
if "/content/test-epcath" not in sys.path:
    sys.path.insert(0, "/content/test-epcath")

import Simulation, Params, VisualizationAnalysis as VA
importlib.reload(Simulation)
importlib.reload(Params)
importlib.reload(VA)
# Out:
# <module 'VisualizationAnalysis' from '/content/test-epcath/VisualizationAnalysis.py'>

# %%
p = Params.Params()
Simulation.applyPriorityRule(p, "longest recovery time first")
policy_results = Simulation.comparePriorityRules(p, saveResults=False)

timePeriod, summary = Simulation.RunSimulation(
    p,
    saveOutputs=False,
    printStats=True,
    printRecommendations=True,
    showVisualizations=True,
    policyResults=policy_results,
    comparisonOptions=options
)
# Out:
# ============================================================
# COMPARISON OF SCHEDULING PRIORITY RULES
# ============================================================
# longest recovery time first: overflow=105, bays_p95=19, close_p95=30:15, mean_util=0.4927
# shortest procedures first: overflow=110, bays_p95=16, close_p95=30:45, mean_util=0.4850
# shortest recovery time first: overflow=132, bays_p95=16, close_p95=31:25, mean_util=0.4909
# longest procedures first: overflow=140, bays_p95=17, close_p95=30:50, mean_util=0.4990
# historical: overflow=144, bays_p95=17, close_p95=31:25, mean_util=0.4939
#
# Recommended scheduling priority rule: longest recovery time first
# Recommended holding bays: 19
# Recommended holding bay close time: 30:15
#
# ...Done!
#
# *********PARAMETERS*********
# Procedure Sorting Priority: historical
# 	sortProcs: True
# 	sortIndex: 7
# 	sortDescend: True
# Scenario: historical
# 	procDataFile: InputData/CathFlatEPFlatShiftsJuly2015.csv
# 	shiftDataFile: InputData/ShiftsFlatFlatJuly2015.csv
# Mean HB Cleaning Time (hours): 0.1
# Resolution (minutes): 5.0
# Cath rooms: 5
# EP rooms: 4
# Post procedure determination random? False
# Pre procedure time converted to hours? False
# Change provider days? False
# Swap provider days? False
# Pre procedure cap implemented? True
#
# *********PROCEDURE DATA*********
# Total procedures: 7402
# Same days: 1014
# Same weeks: 3130
# Emergencies: 0
# 	BREAKDOWN BY MINUTES
# 	Same week flex: 68924.0 minutes
# 	Same week inflex: 362626.6 minutes
# 	Same day flex: 36184.0 minutes
# 	Same day inflex: 449344.8 minutes
# 	Emergency flex: 0 minutes
# 	Emergency inflex: 0 minutes
#
# *********OVERFLOW STATS*********
# Total of 7402 procedures placed
# Total procedures scheduled past closing time: 105
# 	Cath overflow: 68
# 	EP overflow: 37
# 	---
# 	Quarter day shift overflows: 44
# 	Half day shift overflows: 50
# 	Full day shift overflows: 11
# Same day/emergencies overflow during days (0 index): [2, 4, 9, 11, 12, 14, 23, 27, 36, 37, 39, 42, 46, 47, 50, 56, 60, 65, 68, 71, 72, 74, 76, 77, 82, 97, 101, 103, 105, 107, 109, 110, 115, 117, 121, 122, 124, 132, 134, 135, 136, 138, 140, 142, 146, 150, 151, 155, 157, 168, 171, 178, 179, 180, 183, 194, 198, 199, 201, 203, 204, 205, 214, 217, 219, 220, 227, 242, 244, 247, 251, 252, 254]
#
# *********CROSSOVER STATS*********
# Total number of crossover procedures: 0
# Total number of Cath procedures in EP: 0
# Total number of EP procedures in Cath: 0
#
# *********UTILIZATION STATS*********
# Average utilization in Cath over time period: 0.6437739324317775
# Average utilization in EP over time period: 0.34170816974455914
#
# Type: 'avgUtilDay[_day_]' to view average utilization in Cath and EP on a given day (indexed from 0)
# Type: 'avgUtilWeek[_week_]' to view average utilization in Cath and EP during a given week (indexed from 0)
# Type: 'printSchedule(_day_,_labID_,_room_)' to see a specific room day schedule (indexed from 0)
# *********PLANNING RECOMMENDATIONS*********
# Scheduling priority rule tested: longest recovery time first
# Recommended holding bays to build (95th percentile daily peak): 19
# Conservative worst-case peak bays observed: 24
# Recommended holding bay close time (95th percentile last occupied time): 30:15
# Latest observed holding-bay occupancy in simulation: 36:55
# Average room utilization across Cath and EP: 0.4927
# Total procedures placed: 7402
# Total procedures scheduled past room closing time: 105
#
# Close-time sensitivity (proxy using bay-hours after close):
#   Close @ 17:00: days with demand after close = 252, total bay-hours after close = 5238.33, avg/day = 20.1474
#   Close @ 18:00: days with demand after close = 251, total bay-hours after close = 3867.33, avg/day = 14.8744
#   Close @ 19:00: days with demand after close = 249, total bay-hours after close = 2805.75, avg/day = 10.7913
#   Close @ 20:00: days with demand after close = 230, total bay-hours after close = 2011.75, avg/day = 7.7375
#   Close @ 21:00: days with demand after close = 202, total bay-hours after close = 1436.92, avg/day = 5.5266
#   Close @ 22:00: days with demand after close = 176, total bay-hours after close = 1040.83, avg/day = 4.0032
#   Close @ 23:00: days with demand after close = 149, total bay-hours after close = 760.67, avg/day = 2.9256
#   Close @ 24:00: days with demand after close = 129, total bay-hours after close = 544.25, avg/day = 2.0933
#
# *********COST-BASED DECISION SUPPORT*********
# Holding bays meeting service constraint (<=10% days with overcapacity): 18
# Holding bays minimizing total holding-bay cost: 18
# Minimum holding-bay total cost: $106.0
# Best holding-bay close time by total cost: 22:30
# Estimated labor cost at best close time: $660.0
# Estimated admission cost at best close time: $945.3
# Estimated total cost at best close time: $1605.3

# %% [markdown]
# To save the output file for visualization, open Files (Refresh), go to the OutputData folder and Download the "HBDataMelt.csv" file
